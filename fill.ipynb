# %%
import pandas as pd

df = pd.read_excel('data\\Temenos.xlsx', sheet_name='Characteristics (2)')
df
# Out:
# c:\Users\anhvi\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\Users\anhvi\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():
#     STT                                               Name  \
# 0     1  Total number of employees in the reporting per...
# 1     2  Total number of employees in the reporting per...
# 2     3  Total number of employees in the prior period ...
# 3     4  Total number of employees in the prior period ...
# 4     5  Total number of employees, broken down by gend...
# ..  ...                                                ...
# 93   94  percentage of employees per level and by other...
# 94   95  percentage of employees per function and by ot...
# 95   96  percentage of persons with disabilities amongs...
# ...

# %%
gender = "by gender"
df.loc[df["Name"].str.contains(gender.lower()) & df["Value"].isnull(), "Value"] = "Male: ; Female: "

level_gender = "level and by gender"
df.loc[df['Name'].str.contains(level_gender.lower()), 'Value'] = \
    "Management: Male: ; Female: ; Mid-level Management: Male: %; Female: %; Individual Contributor: Male: %; Female: %"
    
df[df['Name'].str.contains(level_gender.lower())]

df.to_excel('data/Temenos_filled.xlsx', index=False)
